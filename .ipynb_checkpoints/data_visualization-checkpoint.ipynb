# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv('gurgaon_properties_missing_value_imputation.csv')

# %%
df.shape
# Out:
# (3554, 18)

# %%
df.head()
# Out:
#   property_type                      society      sector  price  \
# 0          flat      signature global park 4   sector 36   0.82
# 1          flat             smart world gems   sector 89   0.95
# 2          flat       breez global hill view  sohna road   0.32
# 3          flat  bestech park view sanskruti   sector 92   1.60
# 4          flat               suncity avenue  sector 102   0.48
#
#    price_per_sqft  bedRoom  bathroom balcony  floorNum   agePossession  \
# 0          7586.0      3.0       2.0       2       2.0    New Property
# 1          8597.0      2.0       2.0       2       4.0    New Property
# 2          5470.0      2.0       2.0       1      17.0    New Property
# 3          8020.0      3.0       4.0      3+      10.0  Relatively New
# 4          9023.0      2.0       2.0       1       5.0  Relatively New
#
#    built_up_area  study room  servant room  store room  pooja room  others  \
# ...

# %%
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
# I will get average price_per_sqft of each sector and plot in a geomap

# %%
df['sector'].unique()
# Out:
# array(['sector 36', 'sector 89', 'sohna road', 'sector 92', 'sector 102',
#        'gwal pahari', 'sector 108', 'sector 105', 'sector 26',
#        'sector 109', 'sector 28', 'sector 65', 'sector 12', 'sector 85',
#        'sector 70a', 'sector 30', 'sector 107', 'sector 3', 'sector 2',
#        'sector 41', 'sector 4', 'sector 62', 'sector 49', 'sector 81',
#        'sector 66', 'sector 86', 'sector 48', 'sector 51', 'sector 37',
#        'sector 111', 'sector 67', 'sector 113', 'sector 13', 'sector 61',
#        'sector 69', 'sector 67a', 'sector 37d', 'sector 82', 'sector 53',
#        'sector 74', 'sector 52', 'sector 43', 'sector 14', 'sector 25',
#        'sector 95', 'sector 56', 'sector 83', 'sector 104', 'sector 88a',
#        'sector 55', 'sector 50', 'sector 84', 'sector 91', 'sector 76',
#        'sector 82a', 'sector 78', 'manesar', 'sector 93', 'sector 7',
#        'sector 71', 'sector 110', 'sector 33', 'sector 70', 'sector 103',
# ...

# %%
# !pip install shapely
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.7 MB ? eta -:--:--
#    ------------ --------------------------- 0.5/1.7 MB 1.1 MB/s eta 0:00:02
#    ------------------ --------------------- 0.8/1.7 MB 1.3 MB/s eta 0:00:01
#    ------------------------ --------------- 1.0/1.7 MB 1.6 MB/s eta 0:00:01
#    ------------------------------ --------- 1.3/1.7 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------ --- 1.6/1.7 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 1.4 MB/s  0:00:01
# ...
# [notice] A new release of pip is available: 25.2 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install geopandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/23.8 MB ? eta -:--:--
#    ---------------------------------------- 0.3/23.8 MB ? eta -:--:--
#    - -------------------------------------- 0.8/23.8 MB 2.6 MB/s eta 0:00:09
#    -- ------------------------------------- 1.3/23.8 MB 2.3 MB/s eta 0:00:10
#    --- ------------------------------------ 1.8/23.8 MB 2.4 MB/s eta 0:00:10
#    ---- ----------------------------------- 2.6/23.8 MB 2.7 MB/s eta 0:00:08
#    ----- ---------------------------------- 3.4/23.8 MB 3.0 MB/s eta 0:00:07
#    ------- -------------------------------- 4.2/23.8 MB 3.0 MB/s eta 0:00:07
#    ------- -------------------------------- 4.7/23.8 MB 3.1 MB/s eta 0:00:07
#    -------- ------------------------------- 5.2/23.8 MB 2.9 MB/s eta 0:00:07
#    ---------- ----------------------------- 6.0/23.8 MB 3.0 MB/s eta 0:00:06
# ...

# %%
# !pip install folium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
#    ------------- -------------------------- 1/3 [branca]
#    -------------------------- ------------- 2/3 [folium]
#    -------------------------- ------------- 2/3 [folium]
#    -------------------------- ------------- 2/3 [folium]
#    -------------------------- ------------- 2/3 [folium]
#    ---------------------------------------- 3/3 [folium]
#
# ...
# [notice] A new release of pip is available: 25.2 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# # pip install geopandas shapely scipy folium mapclassify --quiet

# import pandas as pd
# import numpy as np
# from scipy.spatial import Voronoi
# from shapely.geometry import Polygon, box
# import geopandas as gpd
# import folium

# # ---------------------------------------------------------------
# # 1. Load & merge your price data with the coords CSV
# # ---------------------------------------------------------------
# price_df = pd.read_csv("gurgaon_properties_missing_value_imputation.csv")            # has 'sector', 'price_per_sqft'
# coords_df = pd.read_csv("gurgaon_sector_coords.csv")      # sector, zone, latitude, longitude

# price_df['sector'] = price_df['sector'].str.lower().str.strip()
# coords_df['sector'] = coords_df['sector'].str.lower().str.strip()

# df = price_df.merge(coords_df, on="sector", how="inner")
# df = df.dropna(subset=["latitude", "longitude", "price_per_sqft"]).reset_index(drop=True)

# # ---------------------------------------------------------------
# # 2. Build Voronoi cells around each sector's point
# #    (this is what fakes the "filled region" choropleth look)
# # ---------------------------------------------------------------
# points = df[["longitude", "latitude"]].values

# # Add far-away dummy points so edge sectors get closed (finite) cells
# pad = 2.0
# bounding = np.array([
#     [points[:,0].min()-pad, points[:,1].min()-pad],
#     [points[:,0].min()-pad, points[:,1].max()+pad],
#     [points[:,0].max()+pad, points[:,1].min()-pad],
#     [points[:,0].max()+pad, points[:,1].max()+pad],
# ])
# vor_points = np.vstack([points, bounding])
# vor = Voronoi(vor_points)

# def voronoi_polygons(vor, n_real_points):
#     """Return list of shapely Polygons, one per real input point (None if unbounded/failed)."""
#     polys = [None] * n_real_points
#     for i in range(n_real_points):
#         region_index = vor.point_region[i]
#         region = vor.regions[region_index]
#         if -1 in region or len(region) == 0:
#             continue
#         poly_pts = [vor.vertices[v] for v in region]
#         polys[i] = Polygon(poly_pts)
#     return polys

# raw_polys = voronoi_polygons(vor, len(points))

# # Clip each cell to a reasonable Gurgaon-ish bounding box so cells don't sprawl
# clip_box = box(76.90, 28.30, 77.16, 28.55)   # roughly greater Gurgaon; adjust if needed
# clipped = [p.intersection(clip_box) if p is not None else None for p in raw_polys]

# df["geometry"] = clipped
# gdf = gpd.GeoDataFrame(df, geometry="geometry", crs="EPSG:4326")
# gdf = gdf[~gdf.geometry.is_empty & gdf.geometry.notna()]

# # ---------------------------------------------------------------
# # 3. Plot as a choropleth with folium
# # ---------------------------------------------------------------
# m = folium.Map(location=[28.43, 77.03], zoom_start=11, tiles="cartodbpositron")

# folium.Choropleth(
#     geo_data=gdf.__geo_interface__,
#     data=gdf,
#     columns=["sector", "price_per_sqft"],
#     key_on="feature.properties.sector",
#     fill_color="YlOrRd",
#     fill_opacity=0.75,
#     line_opacity=0.3,
#     legend_name="Price per sqft (Rs.)",
# ).add_to(m)

# # Add hover tooltips with sector name + price
# folium.GeoJson(
#     gdf.__geo_interface__,
#     style_function=lambda x: {"fillOpacity": 0, "weight": 0},
#     tooltip=folium.GeoJsonTooltip(fields=["sector", "price_per_sqft"],
#                                    aliases=["Sector:", "Price/sqft:"]),
# ).add_to(m)

# m.save("gurgaon_choropleth.html")
# m  # renders inline in Jupyter

# %%
coords_df = pd.read_csv("gurgaon_sector_coords.csv")

# %%
coords_df.sample(10)
# Out:
#          sector         zone  latitude  longitude
# 20     sector 4  old_central  28.46830   77.03517
# 101    sector 8  old_central  28.46148   77.02549
# 54   sector 82a  new_gurgaon  28.37893   77.00912
# 31   sector 113  dwarka_expy  28.50517   76.97493
# 53    sector 76          spr  28.39236   77.05988
# 33    sector 61  golf_ext_rd  28.42084   77.08331
# 99    sector 73          spr  28.39432   77.06124
# 3     sector 92  new_gurgaon  28.37440   77.00831
# 30    sector 67  golf_ext_rd  28.41480   77.07979
# 46    sector 83  new_gurgaon  28.38187   77.00754

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Base URL for Google Search
BASE_URL = "https://www.google.com/search?q="

# Headers to simulate a real browser visit
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}


# Function to scrape latitude and longitude
def get_coordinates(sector):
    search_term = f"sector {sector} gurgaon longitude & latitude"
    response = requests.get(BASE_URL + search_term, headers=HEADERS)

    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        coordinates_div = soup.find("div", class_="Z0LcW t2b5Cf")
        if coordinates_div:
            return coordinates_div.text
    return None


# Create a DataFrame
df = pd.DataFrame(columns=["Sector", "Coordinates"])

# Iterate over sectors and fetch coordinates
# Iterate over sectors and fetch coordinates
rows = []
for sector in range(1, 116):
    coordinates = get_coordinates(sector)
    rows.append({"Sector": f"Sector {sector}", "Coordinates": coordinates})

# Create DataFrame from collected rows
df = pd.DataFrame(rows)

# Save DataFrame
df.to_csv("gurgaon_sectors_coordinates.csv", index=False)

# %%
latlong = pd.read_csv('gurgaon_sectors_coordinates.csv')

# %%
latlong.head()
# Out:
#      Sector  Coordinates
# 0  Sector 1          NaN
# 1  Sector 2          NaN
# 2  Sector 3          NaN
# 3  Sector 4          NaN
# 4  Sector 5          NaN

# %%
new_df = df.merge(coords_df,on='sector')

# %%
df.head()
# Out:
#   property_type                      society      sector  price  \
# 0          flat      signature global park 4   sector 36   0.82
# 1          flat             smart world gems   sector 89   0.95
# 2          flat       breez global hill view  sohna road   0.32
# 3          flat  bestech park view sanskruti   sector 92   1.60
# 4          flat               suncity avenue  sector 102   0.48
#
#    price_per_sqft  bedRoom  bathroom balcony  floorNum   agePossession  \
# 0          7586.0      3.0       2.0       2       2.0    New Property
# 1          8597.0      2.0       2.0       2       4.0    New Property
# 2          5470.0      2.0       2.0       1      17.0    New Property
# 3          8020.0      3.0       4.0      3+      10.0  Relatively New
# 4          9023.0      2.0       2.0       1       5.0  Relatively New
#
#    built_up_area  study room  servant room  store room  pooja room  others  \
# ...

# %%
new_df.head()
# Out:
#   property_type                      society      sector  price  \
# 0          flat      signature global park 4   sector 36   0.82
# 1          flat             smart world gems   sector 89   0.95
# 2          flat       breez global hill view  sohna road   0.32
# 3          flat  bestech park view sanskruti   sector 92   1.60
# 4          flat               suncity avenue  sector 102   0.48
#
#    price_per_sqft  bedRoom  bathroom balcony  floorNum   agePossession  \
# 0          7586.0      3.0       2.0       2       2.0    New Property
# 1          8597.0      2.0       2.0       2       4.0    New Property
# 2          5470.0      2.0       2.0       1      17.0    New Property
# 3          8020.0      3.0       4.0      3+      10.0  Relatively New
# 4          9023.0      2.0       2.0       1       5.0  Relatively New
#
#    built_up_area  study room  servant room  store room  pooja room  others  \
# ...

# %% [markdown]
# ### For the word Cloud

# %%
df1 = pd.read_csv('gurgaon_properties.csv')

# %%
df1.head()
# Out:
#                      property_name property_type                      society  \
# 0    3 BHK Flat in Sector 36 Sohna          flat      signature global park 4
# 1  2 BHK Flat in Sector 89 Gurgaon          flat             smart world gems
# 2  2 BHK Flat in Sector 86 Gurgaon          flat                pyramid elite
# 3              2 BHK Flat in Sohna          flat       breez global hill view
# 4  3 BHK Flat in Sector 92 Gurgaon          flat  bestech park view sanskruti
#
#    price  price_per_sqft     area  \
# 0   0.82          7585.0   1081.0
# 1   0.95          8600.0   1105.0
# 2   0.46            79.0  58228.0
# 3   0.32          5470.0    585.0
# 4   1.60          8020.0   1995.0
#
#                                                                                                              areaWithType  \
# 0                                             Super Built up area 1081(100.43 sq.m.)Carpet area: 650 sq.ft. (60.39 sq.m.)
# ...

# %%
wordcloud_df = df1.merge(df,left_index=True,right_index=True)[['features','sector']]

# %%
wordcloud_df
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   features  \
# ...

# %%
import pickle

def features_to_text(feature_list):
    """Handles both real Python lists and stringified lists like "['Lift(s)', 'Park']" """
    if isinstance(feature_list, str):
        import ast
        try:
            feature_list = ast.literal_eval(feature_list)
        except (ValueError, SyntaxError):
            feature_list = [feature_list]
    if not isinstance(feature_list, (list, tuple)):
        return ""
    return " ".join(str(f) for f in feature_list)

# Build one flattened feature-string per sector
sector_feature_text = {}
for sector, group in wordcloud_df.groupby('sector'):
    all_text = " ".join(features_to_text(f) for f in group['features'])
    sector_feature_text[sector] = all_text

# Save as a dict, keyed by sector
with open('sector_feature_text.pkl', 'wb') as f:
    pickle.dump(sector_feature_text, f)

print(f"Built text for {len(sector_feature_text)} sectors")
print(list(sector_feature_text.keys())[:5])
# Out:
# Built text for 104 sectors
# ['dwarka expressway', 'gwal pahari', 'manesar', 'sector 1', 'sector 10']
